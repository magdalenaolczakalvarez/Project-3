# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %matplotlib inline

# %%
# Files to Load
listings_df= pd.read_csv(r'C:\Users\polska2207\Downloads\calendar (3).csv') 
listings_df
# Out:
#                  listing_id        date available   price adjusted_price  \
# 0                      3686  2023-09-13         f  $67.00         $67.00
# 1                      3686  2023-09-14         f  $67.00         $67.00
# 2                      3686  2023-09-15         f  $67.00         $67.00
# 3                      3686  2023-09-16         f  $67.00         $67.00
# 4                      3686  2023-09-17         f  $67.00         $67.00
# ...                     ...         ...       ...     ...            ...
# 2447276  978844219371308168  2024-09-07         f  $53.00         $53.00
# 2447277  978844219371308168  2024-09-08         f  $53.00         $53.00
# 2447278  978844219371308168  2024-09-09         f  $53.00         $53.00
# 2447279  978844219371308168  2024-09-10         f  $53.00         $53.00
# 2447280  978844219371308168  2024-09-11         f  $53.00         $53.00
#
#          minimum_nights  maximum_nights
# 0                    31             365
# 1                    31             365
# 2                    31             365
# 3                    31             365
# 4                    31             365
# ...                 ...             ...
# 2447276              90             365
# 2447277              90             365
# 2447278              90             365
# 2447279              90             365
# 2447280              90             365
#
# [2447281 rows x 7 columns]

# %%
# Read in primary calendar data 
calendar = pd.read_csv(r'C:\Users\polska2207\Downloads\calendar (3).csv')
# Look at shape of calendar data
calendar.shape
# Out:
# (2447281, 7)

# %%
#Summary Stats
# Look at calendar data
calendar.tail()
# Out:
#                  listing_id        date available   price adjusted_price  \
# 2447276  978844219371308168  2024-09-07         f  $53.00         $53.00
# 2447277  978844219371308168  2024-09-08         f  $53.00         $53.00
# 2447278  978844219371308168  2024-09-09         f  $53.00         $53.00
# 2447279  978844219371308168  2024-09-10         f  $53.00         $53.00
# 2447280  978844219371308168  2024-09-11         f  $53.00         $53.00
#
#          minimum_nights  maximum_nights
# 2447276              90             365
# 2447277              90             365
# 2447278              90             365
# 2447279              90             365
# 2447280              90             365

# %%
calendar.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0        3686  2023-09-13         f  $67.00         $67.00              31
# 1        3686  2023-09-14         f  $67.00         $67.00              31
# 2        3686  2023-09-15         f  $67.00         $67.00              31
# 3        3686  2023-09-16         f  $67.00         $67.00              31
# 4        3686  2023-09-17         f  $67.00         $67.00              31
#
#    maximum_nights
# 0             365
# 1             365
# 2             365
# 3             365
# 4             365

# %%
# sort by date
calendar.sort_values(by='date', ascending=False)
# Out:
#                  listing_id        date available    price adjusted_price  \
# 2447280  978844219371308168  2024-09-11         f   $53.00         $53.00
# 855924             33275075  2024-09-11         t  $385.00        $385.00
# 1407760            50524833  2024-09-11         t  $150.00        $150.00
# 424859             16789250  2024-09-11         f   $30.00         $30.00
# 1089845            42855483  2024-09-11         t  $153.00        $153.00
# ...                     ...         ...       ...      ...            ...
# 1347901            49400352  2023-09-13         f  $100.00        $100.00
# 863590             33611930  2023-09-13         t   $95.00         $95.00
# 2252006  905034790156276131  2023-09-13         f  $999.00        $999.00
# 1347536            49396444  2023-09-13         f   $85.00         $85.00
# 0                      3686  2023-09-13         f   $67.00         $67.00
#
#          minimum_nights  maximum_nights
# 2447280              90             365
# 855924                2              29
# 1407760              60             180
# 424859               31             365
# 1089845             360            1125
# ...                 ...             ...
# 1347901              31            1125
# 863590                1            1125
# 2252006               1             999
# 1347536              31             120
# 0                    31             365
#
# [2447281 rows x 7 columns]

# %%
calendar['listing_id'].value_counts()
# Out:
# 3686                  365
# 588170621472274534    365
# 580379638076900630    365
# 580378577607853975    365
# 580267401769312007    365
#                      ...
# 978844219371308168    365
# 41992846              354
# 41992970              354
# 41993096              354
# 41993155              354
# Name: listing_id, Length: 6705, dtype: int64

# %%
# Check for null values
calendar.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
# fill nans with 0s
calendar['minimum_nights'].fillna(0, inplace=True)
# fill nans with 0s
calendar['maximum_nights'].fillna(0, inplace=True)
# Check data types
calendar.dtypes
# Out:
# listing_id         int64
# date              object
# available         object
# price             object
# adjusted_price    object
# minimum_nights     int64
# maximum_nights     int64
# dtype: object

# %%
# Sort on date column
calendar.sort_values(by='date', ascending=False)
# Out:
#                  listing_id        date available    price adjusted_price  \
# 2447280  978844219371308168  2024-09-11         f   $53.00         $53.00
# 855924             33275075  2024-09-11         t  $385.00        $385.00
# 1407760            50524833  2024-09-11         t  $150.00        $150.00
# 424859             16789250  2024-09-11         f   $30.00         $30.00
# 1089845            42855483  2024-09-11         t  $153.00        $153.00
# ...                     ...         ...       ...      ...            ...
# 1347901            49400352  2023-09-13         f  $100.00        $100.00
# 863590             33611930  2023-09-13         t   $95.00         $95.00
# 2252006  905034790156276131  2023-09-13         f  $999.00        $999.00
# 1347536            49396444  2023-09-13         f   $85.00         $85.00
# 0                      3686  2023-09-13         f   $67.00         $67.00
#
#          minimum_nights  maximum_nights
# 2447280              90             365
# 855924                2              29
# 1407760              60             180
# 424859               31             365
# 1089845             360            1125
# ...                 ...             ...
# 1347901              31            1125
# 863590                1            1125
# 2252006               1             999
# 1347536              31             120
# 0                    31             365
#
# [2447281 rows x 7 columns]
